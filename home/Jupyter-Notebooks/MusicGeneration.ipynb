# %%
# !pip install music21
# Out:
# Requirement already satisfied: music21 in /usr/local/lib/python3.6/dist-packages (5.5.0)

# %%
from music21 import converter,note,chord,stream,instrument
import glob
import pickle
import numpy as np
from keras.utils import np_utils
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# ## Reading and processing the music files

# %%
midi_song = converter.parse('./drive/My Drive/Datasets/midi_songs/EyesOnMePiano.mid')

# %%
midi_song.show('midi')
# Out:
#                 <div id='midiPlayerDiv25301'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv25301');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
#midi_song.show('text')

# %%
elements_to_parse = midi_song.flat.notes
print(type(elements_to_parse))
print(len(elements_to_parse))
# Out:
# <class 'music21.stream.iterator.StreamIterator'>
# 1421

# %%
#for e in elements_to_parse:
    #print(e,e.offset)

# %%
print(elements_to_parse[3])
elements_to_parse[3].pitch
# Out:
# <music21.note.Note A>
# <music21.pitch.Pitch A6>

# %%
print(elements_to_parse[68])
print(elements_to_parse[68].normalOrder)
# Out:
# <music21.chord.Chord F#4 C#5>
# [1, 6]

# %%
'+'.join(str(e) for e in elements_to_parse[68].normalOrder)
# Out:
# '1+6'

# %%
notes_demo = []

for ele in elements_to_parse:
    # if the element is note, then store its pitch
    if isinstance(ele,note.Note):
        notes_demo.append(str(ele.pitch))
    # if the element is a chord, then split the chord into notes and then join them with any operator
    elif isinstance(ele,chord.Chord):
        notes_demo.append('+'.join(str(e) for e in ele.normalOrder))

#print(notes_demo)

# %%
notes = []
for file in glob.glob('./drive/My Drive/Datasets/midi_songs/*.mid'):
    midi = converter.parse(file) 
    elements_to_parse = midi.flat.notes
    print("parsing %s"%file)
    for ele in elements_to_parse:
        # if the element is note, then store its pitch
        if isinstance(ele,note.Note):
            notes.append(str(ele.pitch))
        # if the element is a chord, then split the chord into notes and then join them with any operator
        elif isinstance(ele,chord.Chord):
            notes.append('+'.join(str(e) for e in ele.normalOrder))
#print(notes)
# Out:
# parsing ./drive/My Drive/Datasets/midi_songs/8.mid
# parsing ./drive/My Drive/Datasets/midi_songs/AT.mid
# parsing ./drive/My Drive/Datasets/midi_songs/BlueStone_LastDungeon.mid
# parsing ./drive/My Drive/Datasets/midi_songs/0fithos.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Still_Alive-1.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FFIX_Piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Fyw_piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/balamb.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Ff7-Jenova_Absolute.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Kingdom_Hearts_Traverse_Town.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff4-fight1.mid
# parsing ./drive/My Drive/Datasets/midi_songs/decisive.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FF4.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FF8_Shuffle_or_boogie_pc.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff4_piano_collections-main_theme.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff4-town.mid
# parsing ./drive/My Drive/Datasets/midi_songs/lurk_in_dark.mid
# parsing ./drive/My Drive/Datasets/midi_songs/figaro.mid
# parsing ./drive/My Drive/Datasets/midi_songs/mining.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Zelda_Overworld.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff4pclov.mid
# parsing ./drive/My Drive/Datasets/midi_songs/HighwindTakestotheSkies.mid
# parsing ./drive/My Drive/Datasets/midi_songs/redwings.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FFVII_BATTLE.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Finalfantasy6fanfarecomplete.mid
# parsing ./drive/My Drive/Datasets/midi_songs/OTD5YA.mid
# parsing ./drive/My Drive/Datasets/midi_songs/fortresscondor.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Final_Fantasy_Matouyas_Cave_Piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/VincentPiano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/goldsaucer.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff7-mainmidi.mid
# parsing ./drive/My Drive/Datasets/midi_songs/path_of_repentance.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Fierce_Battle_(Piano).mid
# parsing ./drive/My Drive/Datasets/midi_songs/Rachel_Piano_tempofix.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Rydia_pc.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Oppressed.mid
# parsing ./drive/My Drive/Datasets/midi_songs/bcm.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ViviinAlexandria.mid
# parsing ./drive/My Drive/Datasets/midi_songs/EyesOnMePiano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FF3_Battle_(Piano).mid
# parsing ./drive/My Drive/Datasets/midi_songs/dontbeafraid.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/electric_de_chocobo.mid
# parsing ./drive/My Drive/Datasets/midi_songs/gerudo.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Gold_Silver_Rival_Battle.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FF3_Third_Phase_Final_(Piano).mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff4-airship.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff1battp.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Life_Stream.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Ff4-BattleLust.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Cids.mid
# parsing ./drive/My Drive/Datasets/midi_songs/braska.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Final_Fantasy_7_-_Judgement_Day_Piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FF6epitaph_piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff11_awakening_piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/DOS.mid
# parsing ./drive/My Drive/Datasets/midi_songs/great_war.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Finalfantasy5gilgameshp.mid
# parsing ./drive/My Drive/Datasets/midi_songs/cosmo.mid
# parsing ./drive/My Drive/Datasets/midi_songs/JENOVA.mid
# parsing ./drive/My Drive/Datasets/midi_songs/FFIXQuMarshP.mid
# parsing ./drive/My Drive/Datasets/midi_songs/pkelite4.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff8-lfp.mid
# parsing ./drive/My Drive/Datasets/midi_songs/dayafter.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Kingdom_Hearts_Dearly_Beloved.mid
# parsing ./drive/My Drive/Datasets/midi_songs/costadsol.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Fiend_Battle_(Piano).mid
# parsing ./drive/My Drive/Datasets/midi_songs/Ff7-Cinco.mid
# parsing ./drive/My Drive/Datasets/midi_songs/caitsith.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Eternal_Harvest.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff6shap.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ff7themep.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Ff7-One_Winged.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ahead_on_our_way_piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/In_Zanarkand.mid
# parsing ./drive/My Drive/Datasets/midi_songs/thoughts.mid
# parsing ./drive/My Drive/Datasets/midi_songs/sandy.mid
# parsing ./drive/My Drive/Datasets/midi_songs/roseofmay-piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/thenightmarebegins.mid
# parsing ./drive/My Drive/Datasets/midi_songs/tpirtsd-piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ultros.mid
# parsing ./drive/My Drive/Datasets/midi_songs/waltz_de_choco.mid
# parsing ./drive/My Drive/Datasets/midi_songs/sobf.mid
# parsing ./drive/My Drive/Datasets/midi_songs/relmstheme-piano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/rufus.mid
# parsing ./drive/My Drive/Datasets/midi_songs/sera_.mid
# parsing ./drive/My Drive/Datasets/midi_songs/z_aeristhemepiano.mid
# parsing ./drive/My Drive/Datasets/midi_songs/traitor.mid
# parsing ./drive/My Drive/Datasets/midi_songs/tifap.mid
# parsing ./drive/My Drive/Datasets/midi_songs/ultimafro.mid
# parsing ./drive/My Drive/Datasets/midi_songs/output.mid
# parsing ./drive/My Drive/Datasets/midi_songs/Can't-Help-Falling-In-Love-With-You-1.mid
# parsing ./drive/My Drive/Datasets/midi_songs/thousand_years.mid
# parsing ./drive/My Drive/Datasets/midi_songs/couldyou.mid

# %%
n_vocab = len(set(notes))
print(len(notes))
print(n_vocab)
# Out:
# 65730
# 381

# %%
print("Total len of vocab %d \nUnique elements of vocab %d"%(len(notes),n_vocab))
# Out:
# Total len of vocab 65730
# Unique elements of vocab 381

# %%
import os
import pickle

# %%
with open("./drive/My Drive/PreprocessedData/notes",'wb') as f:
    pickle.dump(notes,f)
f.close()

# %%
with open('./drive/My Drive/PreprocessedData/notes','rb') as f:
    note_load = pickle.load(f)
f.close()

# %%
n_vocab = len(set(notes))
print(len(notes))
print(n_vocab)
# Out:
# 65730
# 381

# %% [markdown]
# ## Generating the sequential data for the LSTM model

# %%
notes = note_load

# %%
snotes = sorted(set(notes))

# %%
ele_int = dict((ele,idx) for idx,ele in enumerate(snotes))

# %%
ele_int["F#2"]
n = np.array(notes)
n[n=="F#4"].shape
#n.shape
# Out:
# (868,)

# %%
sequence_length = 50

network_input = []
network_output = []

for i in range(len(notes) - sequence_length):
    seq_in = notes[i:i+sequence_length] # in the string format
    seq_out = notes[i+sequence_length]
    
    network_input.append([ele_int[ch] for ch in seq_in])
    network_output.append(ele_int[seq_out])

# %%
print(len(network_input))
n_patterns = len(network_input)
print(network_input[0])
# Out:
# 65680
# [333, 352, 330, 333, 352, 330, 378, 378, 333, 333, 340, 66, 308, 340, 66, 308, 366, 366, 311, 311, 367, 275, 363, 367, 275, 363, 304, 275, 363, 304, 275, 363, 379, 83, 375, 379, 83, 375, 353, 333, 330, 353, 333, 330, 330, 330, 378, 378, 333, 333]

# %%
print(len(network_output))
# Out:
# 65680

# %%
network_input = np.reshape(network_input,(n_patterns,sequence_length,1))
print(network_input.shape)
# Out:
# (65680, 50, 1)

# %%
# Normalize our data [0,1]
normalized_network_input = network_input/float(n_vocab)
#print(normalized_network_input)

# %%
# Converting the y values into one hot vectors
network_output = np_utils.to_categorical(network_output)
print(network_output.shape)
# Out:
# (65680, 381)

# %%
print(normalized_network_input.shape)
print(network_output.shape)
# Out:
# (65680, 50, 1)
# (65680, 381)

# %% [markdown]
# ## Creating the LSTM model

# %%
from keras.models import Sequential,load_model
from keras.layers import *
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.metrics import classification_report,confusion_matrix
from keras.optimizers import Adam

# %%
adam = Adam(lr = 1e-3)

# %%
model = Sequential()
model.add(LSTM(512,input_shape = (normalized_network_input.shape[1],normalized_network_input.shape[2]),return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(512, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(512))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(n_vocab,activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy',optimizer = adam)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 50, 512)           1052672
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50, 512)           0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 50, 512)           2099200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50, 512)           0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 381)               195453
# =================================================================
# Total params: 5,709,181
# Trainable params: 5,709,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint("model.hdf5",monitor='loss',verbose=0,save_best_only=True,mode = 'min')

hist = model.fit(normalized_network_input,network_output,epochs = 100,batch_size = 1024,callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 65680/65680 [==============================] - 57s 866us/step - loss: 4.8638
# Epoch 2/100
# 65680/65680 [==============================] - 56s 850us/step - loss: 4.7411
# Epoch 3/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.7314
# Epoch 4/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.7259
# Epoch 5/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 4.7220
# Epoch 6/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.7201
# Epoch 7/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 4.6885
# Epoch 8/100
# 65680/65680 [==============================] - 56s 852us/step - loss: 4.5849
# Epoch 9/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.5441
# Epoch 10/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 4.5266
# Epoch 11/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.5081
# Epoch 12/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 4.4893
# Epoch 13/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 4.4820
# Epoch 14/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.4556
# Epoch 15/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 4.4301
# Epoch 16/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 4.3927
# Epoch 17/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 4.3523
# Epoch 18/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 4.2986
# Epoch 19/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 4.2913
# Epoch 20/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 4.1971
# Epoch 21/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 4.1484
# Epoch 22/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 4.0686
# Epoch 23/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 3.9888
# Epoch 24/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 3.9196
# Epoch 25/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 3.8264
# Epoch 26/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 3.7179
# Epoch 27/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 3.6199
# Epoch 28/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 3.4839
# Epoch 29/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 3.3773
# Epoch 30/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 3.2563
# Epoch 31/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 3.1349
# Epoch 32/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 3.0263
# Epoch 33/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 2.9073
# Epoch 34/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 2.8104
# Epoch 35/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 2.6630
# Epoch 36/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 2.5603
# Epoch 37/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 2.4518
# Epoch 38/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 2.3820
# Epoch 39/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 2.2476
# Epoch 40/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 2.1564
# Epoch 41/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 2.0711
# Epoch 42/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 1.9710
# Epoch 43/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.8842
# Epoch 44/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 1.8212
# Epoch 45/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.7221
# Epoch 46/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.6601
# Epoch 47/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.6436
# Epoch 48/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 1.5100
# Epoch 49/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.4447
# Epoch 50/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.4039
# Epoch 51/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 1.3266
# Epoch 52/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 1.2740
# Epoch 53/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 1.2409
# Epoch 54/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.1871
# Epoch 55/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.1026
# Epoch 56/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 1.0696
# Epoch 57/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 1.0068
# Epoch 58/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 1.0125
# Epoch 59/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.9359
# Epoch 60/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.8917
# Epoch 61/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.8590
# Epoch 62/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.8390
# Epoch 63/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.8030
# Epoch 64/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.7731
# Epoch 65/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.7207
# Epoch 66/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 0.6994
# Epoch 67/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.6646
# Epoch 68/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 0.6433
# Epoch 69/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.6274
# Epoch 70/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.6110
# Epoch 71/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.5797
# Epoch 72/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.5584
# Epoch 73/100
# 65680/65680 [==============================] - 56s 859us/step - loss: 0.5590
# Epoch 74/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.5401
# Epoch 75/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 0.4975
# Epoch 76/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.4752
# Epoch 77/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.4515
# Epoch 78/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.4359
# Epoch 79/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 0.4412
# Epoch 80/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 0.4260
# Epoch 81/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.4023
# Epoch 82/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3992
# Epoch 83/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3786
# Epoch 84/100
# 65680/65680 [==============================] - 56s 858us/step - loss: 0.3652
# Epoch 85/100
# 65680/65680 [==============================] - 56s 857us/step - loss: 0.3555
# Epoch 86/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3781
# Epoch 87/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3534
# Epoch 88/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.3356
# Epoch 89/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3158
# Epoch 90/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3333
# Epoch 91/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.3039
# Epoch 92/100
# 65680/65680 [==============================] - 56s 856us/step - loss: 0.2923
# Epoch 93/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 0.2885
# Epoch 94/100
# 65680/65680 [==============================] - 56s 853us/step - loss: 0.2836
# Epoch 95/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.2626
# Epoch 96/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.8092
# Epoch 97/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.3137
# Epoch 98/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.2535
# Epoch 99/100
# 65680/65680 [==============================] - 56s 855us/step - loss: 0.2402
# Epoch 100/100
# 65680/65680 [==============================] - 56s 854us/step - loss: 0.2288

# %%
model.save("model.hdf5")

# %% [markdown]
# ## Making predictions on the model

# %%
model = load_model("model.hdf5")

# %%
sequence_length = 50
network_input = []
for i in range(len(notes) - sequence_length):
    seq_in = notes[i:i+sequence_length] # in the string format
    network_input.append([ele_int[ch] for ch in seq_in])

# %%
# Taking a random start sequence to generate the next sequence
start = np.random.randint(len(network_input))
pattern = network_input[start]
prediction_output = []
int_to_ele = dict((idx,ele)for idx,ele in enumerate(snotes))

for i in range(200):
    prediction_input = np.reshape(pattern,(1,sequence_length,1))
    prediction_input = prediction_input/float(n_vocab)
    
    prediction = model.predict(prediction_input)
    idx = np.argmax(prediction)
    prediction_output.append(int_to_ele[idx])
    
    pattern.append(idx)
    pattern = pattern[1:]

# %%
print(prediction_output)
# Out:
# ['A4', '0+5', 'C5', 'A4', 'E5', 'C5', 'B4', 'D5', 'E5', '4+9', 'C5', 'A4', '0+5', '4+9', 'C5', 'A4', 'F#5', 'C5', 'A4', '0+5', 'C5', 'A4', 'E5', 'E3', 'C5', 'B2', 'B4', 'C3', 'D5', 'G#2', 'E5', '4+9', 'C5', 'A4', '0+5', '4+9', 'C5', 'A4', 'F#5', '4+9', 'C5', 'A4', '0+5', '4+9', 'C5', 'A4', 'E5', '4+9', 'C5', 'B4', '7', 'D5', 'E5', '4+9', 'C5', 'A4', '0+5', '4+9', 'C5', 'A4', 'F#5', '4+9', 'C5', 'A4', '0+5', '4+9', 'C5', 'A4', 'E5', '4+9', 'C5', 'B4', '7', 'D5', '9+0', '5', '4+7', '2+5', '7', '0+4', '11+2', '4', '0+4', 'E4', '2+5', '11', '11+2', '5', '7+11', '7', '9+0', '9', '11', '0', '4', 'A4', '5', 'F4', 'E5', 'A4', 'D5', '7', 'C5', 'A4', 'B4', '4', 'G4', 'C5', 'E4', 'D5', '11', 'G4', 'B4', '5', 'E4', 'G4', '7', 'E4', '4+9', '4+9', '4+9', '4+9', '4+9', '4+9', '2+7', '4+9', '4+9', '4+9', '4+9', '4+9', '2+7', 'E4', '4+9', 'A4', 'B4', 'C5', '4+9', 'B4', 'A4', 'E4', '4+9', 'C4', 'B3', '4+9', 'C4', 'A3', '4+9', 'C4', 'B3', '7', 'C4', 'D4', '5', 'E4', 'C4', '5', 'E4', 'D4', '4', 'E4', 'F4', 'B3', '2', 'C4', 'F4', '4+9', '4', 'D4', '4+8', '4', 'D4', 'A4', '4+9', 'E4', 'A4', 'C5', '4+9', 'B4', 'A4', 'E4', '4+9', 'C4', 'B3', '4+9', 'C4', 'A3', '4+9', 'C4', 'B3', '7', 'C4', 'D4', '5', 'E4', 'C4', '5', 'E4', 'D4', '4', 'E4']

# %% [markdown]
# ## Creating a MIDI file to play the music generated by the model

# %%
output_notes = []
offset = 0

for pattern in prediction_output:
    #if the pattern is a chord, then
    if ('+' in pattern) or pattern.isdigit():
        all_notes = pattern.split("+")
        temp_notes = []
        #print(all_notes)
        for current_note in all_notes:
          new_note = note.Note(int(current_note))
          new_note.storedInstrument = instrument.Piano()
          temp_notes.append(new_note)
        new_chord = chord.Chord(temp_notes) # It creates a chord with the help of the list of the notes
        new_chord.storedInstrument = instrument.Piano()
        output_notes.append(new_chord)
        
    else:
        #if the pattern is a note,then
        new_note = note.Note(pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)
    offset += 0.5

# %%
print(output_notes)
# Out:
# [<music21.note.Note A>, <music21.chord.Chord C F>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note E>, <music21.note.Note C>, <music21.note.Note B>, <music21.note.Note D>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord C F>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note F#>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord C F>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note E>, <music21.note.Note E>, <music21.note.Note C>, <music21.note.Note B>, <music21.note.Note B>, <music21.note.Note C>, <music21.note.Note D>, <music21.note.Note G#>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord C F>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note F#>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord C F>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note B>, <music21.chord.Chord G>, <music21.note.Note D>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord C F>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note F#>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord C F>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note B>, <music21.chord.Chord G>, <music21.note.Note D>, <music21.chord.Chord A C>, <music21.chord.Chord F>, <music21.chord.Chord E G>, <music21.chord.Chord D F>, <music21.chord.Chord G>, <music21.chord.Chord C E>, <music21.chord.Chord B D>, <music21.chord.Chord E>, <music21.chord.Chord C E>, <music21.note.Note E>, <music21.chord.Chord D F>, <music21.chord.Chord B>, <music21.chord.Chord B D>, <music21.chord.Chord F>, <music21.chord.Chord G B>, <music21.chord.Chord G>, <music21.chord.Chord A C>, <music21.chord.Chord A>, <music21.chord.Chord B>, <music21.chord.Chord C>, <music21.chord.Chord E>, <music21.note.Note A>, <music21.chord.Chord F>, <music21.note.Note F>, <music21.note.Note E>, <music21.note.Note A>, <music21.note.Note D>, <music21.chord.Chord G>, <music21.note.Note C>, <music21.note.Note A>, <music21.note.Note B>, <music21.chord.Chord E>, <music21.note.Note G>, <music21.note.Note C>, <music21.note.Note E>, <music21.note.Note D>, <music21.chord.Chord B>, <music21.note.Note G>, <music21.note.Note B>, <music21.chord.Chord F>, <music21.note.Note E>, <music21.note.Note G>, <music21.chord.Chord G>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord D G>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord E A>, <music21.chord.Chord D G>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note A>, <music21.note.Note B>, <music21.note.Note C>, <music21.chord.Chord E A>, <music21.note.Note B>, <music21.note.Note A>, <music21.note.Note E>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note B>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note A>, <music21.chord.Chord E A>, <music21.note.Note C>, <music21.note.Note B>, <music21.chord.Chord G>, <music21.note.Note C>, <music21.note.Note D>, <music21.chord.Chord F>, <music21.note.Note E>, <music21.note.Note C>, <music21.chord.Chord F>, <music21.note.Note E>, <music21.note.Note D>, <music21.chord.Chord E>, <music21.note.Note E>, <music21.note.Note F>, <music21.note.Note B>, <music21.chord.Chord D>, <music21.not ...

# %%
midi_stream = stream.Stream(output_notes)
midi_stream.write("midi","/content/drive/My Drive/MLplayground/output1.mid")
# Out:
# '/content/drive/My Drive/MLplayground/output1.mid'

# %%
midi_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv476214'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv476214');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
